# %%
# !uv add  coqui-tts
# Out:
# Resolved 248 packages in 5.86s
# Prepared 86 packages in 1m 52s
# Installed 86 packages in 1m 08s
#  + absl-py==2.2.2
#  + aiohappyeyeballs==2.6.1
#  + aiohttp==3.11.18
#  + aiosignal==1.3.2
#  + anyascii==0.3.2
#  + audioread==3.0.1
#  + contourpy==1.3.2
#  + coqpit-config==0.2.0
#  + coqui-tts==0.26.1
#  + coqui-tts-trainer==0.2.3
#  + cycler==0.12.1
#  + cython==3.1.0
#  + dateparser==1.1.8
#  + docopt==0.6.2
#  + einops==0.8.1
#  + encodec==0.1.1
#  + filelock==3.18.0
#  + fonttools==4.58.0
#  + frozenlist==1.6.0
#  + fsspec==2025.3.2
#  + grpcio==1.71.0
#  + gruut==2.4.0
#  + gruut-ipa==0.13.0
#  + gruut-lang-de==2.0.1
#  + gruut-lang-en==2.0.1
#  + gruut-lang-es==2.0.1
#  + gruut-lang-fr==2.0.2
#  + huggingface-hub==0.31.2
#  + inflect==7.5.0
#  + joblib==1.5.0
#  + jsonlines==1.2.0
#  + kiwisolver==1.4.8
#  + lazy-loader==0.4
#  + librosa==0.11.0
#  + llvmlite==0.44.0
#  + markdown==3.8
#  + matplotlib==3.10.3
#  + monotonic-alignment-search==0.1.1
#  + more-itertools==10.7.0
#  + mpmath==1.3.0
#  + msgpack==1.1.0
#  + multidict==6.4.3
#  + networkx==3.4.2
#  + num2words==0.5.14
#  + numba==0.61.2
#  + nvidia-cublas-cu12==12.6.4.1
#  + nvidia-cuda-cupti-cu12==12.6.80
#  + nvidia-cuda-nvrtc-cu12==12.6.77
#  + nvidia-cuda-runtime-cu12==12.6.77
#  + nvidia-cudnn-cu12==9.5.1.17
#  + nvidia-cufft-cu12==11.3.0.4
#  + nvidia-cufile-cu12==1.11.1.6
#  + nvidia-curand-cu12==10.3.7.77
#  + nvidia-cusolver-cu12==11.7.1.2
#  + nvidia-cusparse-cu12==12.5.4.2
#  + nvidia-cusparselt-cu12==0.6.3
#  + nvidia-nccl-cu12==2.26.2
#  + nvidia-nvjitlink-cu12==12.6.85
#  + nvidia-nvtx-cu12==12.6.77
#  + pillow==11.2.1
#  + pooch==1.8.2
#  + propcache==0.3.1
#  + protobuf==6.31.0
#  + pyparsing==3.2.3
#  + pysbd==0.3.4
#  + python-crfsuite==0.9.11
#  + regex==2024.11.6
#  + safetensors==0.5.3
#  + scikit-learn==1.6.1
#  + scipy==1.15.3
#  + soundfile==0.13.1
#  + soxr==0.5.0.post1
#  + sympy==1.14.0
#  + tensorboard==2.19.0
#  + tensorboard-data-server==0.7.2
#  + threadpoolctl==3.6.0
#  + tokenizers==0.21.1
#  + torch==2.7.0
#  + torchaudio==2.7.0
#  + tqdm==4.67.1
#  + transformers==4.51.3
#  + triton==3.3.0
#  + typeguard==4.4.2
#  + tzlocal==5.3.1
#  + werkzeug==3.1.3
#  + yarl==1.20.0

# %%
from TTS.api import TTS
import torch
from IPython.display import Audio


# Выбор устройства
device = "cuda" if torch.cuda.is_available() else "cpu"

tts = TTS("tts_models/multilingual/multi-dataset/xtts_v2").to(device)
# Out:
#  > You must confirm the following:
#  | > "I have purchased a commercial license from Coqui: licensing@coqui.ai"
#  | > "Otherwise, I agree to the terms of the non-commercial CPML: https://coqui.ai/cpml" - [y/n]
#  | | >  y
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████▋| 1.86G/1.87G [00:20<00:00, 93.1MiB/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████| 1.87G/1.87G [00:20<00:00, 91.3MiB/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████| 4.37k/4.37k [00:00<00:00, 19.3kiB/s]
#  55%|███████████████████████████████████████████████████████▊                                              | 198k/361k [00:00<00:00, 932kiB/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████| 361k/361k [00:00<00:00, 565kiB/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 32.0/32.0 [00:00<00:00, 133iB/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████| 7.75M/7.75M [00:18<00:00, 21.9MiB/s]

# %%
# generate speech by cloning a voice using default settings
tts.tts_to_file(text="Добрый день, Я сегодня уже отвечал на этот вопрос на лекции, Спросите у одногруппников",
                file_path="output.wav",
                speaker="Viktor Menelaos",
                language="ru",
                # split_sentences=True
                )

# Воспроизведение аудиофайла
Audio("output.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
